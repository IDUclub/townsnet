# %%
import pandas as pd
from pathlib import Path
from townsnet.provision.model import UrbanFunctionCalculator
pd.set_option('future.no_silent_downcasting', True)

# Пути к данным
CITY_INFO_PATH = Path("data/city/towns.geojson")
SERVICE_FILES = Path('data/services')

# Загрузка данных и расчет аналитических показателей
model = UrbanFunctionCalculator()
model.load_city_info(CITY_INFO_PATH)
model.city_info.index = list(range(207, len(model.city_info) + 207))
model.load_service_results(SERVICE_FILES)

# Построение профилей городов (аналитический метод)
# min_export_threshold - минимальный порог экспорта услуг для ПОП
profiles = model.build_profiles(min_export_threshold=1000)
gdf = model.get_profilies()

# Получаем список ПОП по аналитическому методу
analytical_pops = gdf[gdf['Потенциальный опорный пункт'] == True].copy()
print(f"Аналитический метод: найдено {len(analytical_pops)} потенциальных опорных пунктов")

# %%
profiles[328]

# %%
gdf.head(5)

# %%
# Расчет ML-признаков
_ = model.compute_ml_features(
    n_clusters=4,
    components=2,
    with_anomaly=True,
    random_state=42
)

# Могут быть не все услуги переданы изначально, поэтому смотрим, сколько типов услуг имеем
print(f"Готово: {len(gdf)} городов, {len(model.service_aggregates)} услуг.")

# %%
result = model.analyze_cluster(
    cluster_id=3,                   # номер кластера
    anomaly_quantile=0.95,          # квантиль для разделния на аномальные города
    pop_provision_quantile=0.85,    # квантиль обеспеченности ПОП
    pop_anomaly_quantile=0.75,      # квантиль для выбора аномальных городов как ПОП
    typical_provision_quantile=0.1, # квантиль обеспеченности для выбора наиболее типичных городов
    figsize=(14, 6),
    show_plots=True,
    show_map=True
)

# %%
typical_low_provision = pd.DataFrame(result['typical_low_provision']) # получаем список городов с низким уровнем обеспеченности

# %%
model.ml_features.loc[typical_low_provision['city_id']].explore('service_provision_index', tiles='CartoDB Positron') # просмотр карты городов с низким уровнем обеспеченности

# %%
display(result.keys())
anomalies = pd.DataFrame(result['anomalies'])
model.ml_features.loc[anomalies['city_id']].explore(tiles='CartoDB Positron')
