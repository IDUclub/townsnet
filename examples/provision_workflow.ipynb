# %%
from pathlib import Path
import json

import pandas as pd
import geopandas as gpd
from townsnet.provision.model import UrbanFunctionCalculator

# %%
CITY_INFO_PATH = Path("data/townsnet10/towns2.geojson")
SERVICE_FILES = Path('data/services')
OUTPUT_JSON = Path("data/townsnet10/city_profiles.json")

# %%
model = UrbanFunctionCalculator()
model.load_city_info(CITY_INFO_PATH)
model.city_info.index = list(range(207, len(model.city_info) + 207))

model.load_service_results(SERVICE_FILES)
profiles = model.build_profiles()

print(f"Сформировано профилей: {len(profiles)}")
# Out:
# Сформировано профилей: 2931

# %%
print(json.dumps({328: profiles[328]}, ensure_ascii=False, indent=2))
# Out:
# {
#   "328": {
#     "Название": "Бокситогорск",
#     "Опорный город": true,
#     "Потенциальный опорный пункт": false,
#     "Население": 8001,
#     "Лучшая обеспеченность, %": 100.0,
#     "Сервисы: обеспеченность": {
#       "Детский сад": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 946
#       },
#       "Школа": {
#         "Обеспеченность, %": 80.43,
#         "Обслуженное население": 1496
#       },
#       "Дом детского творчества": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Детские лагеря": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Среднее специальное учебное заведение": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Высшее учебное заведение": {
#         "Обеспеченность, %": 61.88,
#         "Обслуженное население": 125
#       },
#       "Поликлиника": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 202
#       },
#       "Детская поликлиника": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Стоматологическая клиника": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Фельдшерско-акушерский пункт": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Женская консультация": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Реабилитационный центр": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Аптека": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 233
#       },
#       "Больница": {
#         "Обеспеченность, %": 20.0,
#         "Обслуженное население": 28
#       },
#       "Роддом": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Детская больница": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Хоспис": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Станция скорой медицинской помощи": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Травматологические пункты": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Морг": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Диспансер": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Санаторий": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Бассейн": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 124
#       },
#       "Спортивный зал": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Стадион": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 155
#       },
#       "Ледовая арена": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Каток": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Скалодром": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Дом престарелых": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Детские дома-интернаты": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Центр занятости населения": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Почтовое отделение": {
#         "Обеспеченность, %": 41.38,
#         "Обслуженное население": 5982
#       },
#       "Пункт выдачи": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Отделение банка": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 310
#       },
#       "Банкомат": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Многофункциональные центры (МФЦ)": {
#         "Обеспеченность, %": 47.98,
#         "Обслуженное население": 3033
#       },
#       "Адвокат": {
#         "Обеспеченность, %": 25.35,
#         "Обслуженное население": 55
#       },
#       "Нотариальная контора": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Парикмахер": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 155
#       },
#       "Салон красоты": {
#         "Обеспеченность, %": 63.23,
#         "Обслуженное население": 98
#       },
#       "Общественная баня": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Ветеринарная клиника": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Зоомагазин": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Библиотека": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Дворец культуры": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Музей": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 47
#       },
#       "Театр": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Кинотеатр": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 140
#       },
#       "Торговый центр": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 124
#       },
#       "Аквапарк": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Парк": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 2325
#       },
#       "Полицейский участок": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 78
#       },
#       "Пожарная станция": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Гостиница": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 140
#       },
#       "Хостел": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "База отдыха": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Кафе": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 388
#       },
#       "Ресторан": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Бар/Паб": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Столовая": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Булочная": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 124
#       }
#     },
#     "Сервисы: мобильность": {
#       "Детский сад": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Школа": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Дом детского творчества": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Детские лагеря": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Среднее специальное учебное заведение": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Высшее учебное заведение": {
#         "Внешний спрос": 77.0,
#         "Доля внешнего спроса, %": 38.12
#       },
#       "Поликлиника": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Детская поликлиника": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Стоматологическая клиника": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Фельдшерско-акушерский пункт": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Женская консультация": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Реабилитационный центр": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Аптека": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Больница": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Роддом": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Детская больница": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Хоспис": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Станция скорой медицинской помощи": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Травматологические пункты": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Морг": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Диспансер": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Санаторий": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Бассейн": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Спортивный зал": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Стадион": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Ледовая арена": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Каток": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Скалодром": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Дом престарелых": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Детские дома-интернаты": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Центр занятости населения": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Почтовое отделение": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Пункт выдачи": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Отделение банка": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Банкомат": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Многофункциональные центры (МФЦ)": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Адвокат": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Нотариальная контора": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Парикмахер": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Салон красоты": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Общественная баня": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Ветеринарная клиника": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Зоомагазин": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Библиотека": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Дворец культуры": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Музей": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Театр": {
#         "Внешний спрос": 93.0,
#         "Доля внешнего спроса, %": 100.0
#       },
#       "Кинотеатр": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Торговый центр": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Аквапарк": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Парк": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Полицейский участок": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Пожарная станция": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Гостиница": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Хостел": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "База отдыха": {
#         "Внешний спрос": 155.0,
#         "Доля внешнего спроса, %": 100.0
#       },
#       "Кафе": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Ресторан": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Бар/Паб": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Столовая": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Булочная": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       }
#     },
#     "Градообслуживающие функции": {
#       "Образование": {
#         "Обеспеченность, %": 85.34,
#         "Обслуженное население": 2567
#       },
#       "Здравоохранение": {
#         "Обеспеченность, %": 80.52,
#         "Обслуженное население": 463
#       },
#       "Спорт": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 279
#       },
#       "Социальная помощь": {
#         "Обеспеченность, %": 0.0,
#         "Обслуженное население": 0
#       },
#       "Услуги": {
#         "Обеспеченность, %": 44.57,
#         "Обслуженное население": 9633
#       },
#       "Культура и отдых": {
#         "Обеспеченность, %": 96.78,
#         "Обслуженное население": 2791
#       },
#       "Безопасность": {
#         "Обеспеченность, %": 100.0,
#         "Обслуженное население": 78
#       },
#       "Туризм": {
#         "Обеспеченность, %": 26.77,
#         "Обслуженное население": 652
#       }
#     },
#     "Градообразующие функции": {
#       "Образование": {
#         "Внешний спрос": 77.0,
#         "Доля внешнего спроса, %": 2.56
#       },
#       "Здравоохранение": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Спорт": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Социальная помощь": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Услуги": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Культура и отдых": {
#         "Внешний спрос": 93.0,
#         "Доля внешнего спроса, %": 3.22
#       },
#       "Безопасность": {
#         "Внешний спрос": 0.0,
#         "Доля внешнего спроса, %": 0.0
#       },
#       "Туризм": {
#         "Внешний спрос": 155.0,
#         "Доля внешнего спроса, %": 6.36
#       }
#     },
#     "Лучшая градообслуживающая функция": "Спорт",
#     "Лучшая градообслуживающая функция, %": 100.0,
#     "Лучшая градообразующая функция": "Туризм",
#     "Лучшая градообразующая функция, %": 6.36
#   }
# }

# %%
OUTPUT_JSON.parent.mkdir(parents=True, exist_ok=True)
model.save_city_json(OUTPUT_JSON, by="id")
print(f"Результат сохранён в {OUTPUT_JSON}")
