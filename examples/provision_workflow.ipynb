# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import json

import numpy as np
import pandas as pd
import geopandas as gpd
from townsnet.provision.model import UrbanFunctionCalculator

# %%
CITY_INFO_PATH = Path("data/city/towns.geojson")
SERVICE_FILES = Path('data/services')
OUTPUT_JSON = Path("data/city/city_profiles.json")

# %%
model = UrbanFunctionCalculator()
model.load_city_info(CITY_INFO_PATH)
model.city_info.index = list(range(207, len(model.city_info) + 207))

model.load_service_results(SERVICE_FILES)
model.compute_ml_features(n_clusters=4, components=2, with_anomaly=True)
profiles = model.build_profiles(min_export_threshold=0)

print(f"Сформировано профилей: {len(profiles)}")
# Out:
# Сформировано профилей: 2931

# %%
from pprint import pprint
pprint(profiles[1822])
# Out:
# {'ML': {'anomaly': 0.05378013942880322,
#         'cluster': 1,
#         'embedding': [7.505321692152032, -5.562132175642464],
#         'index': 94.754823781794},
#  'geometry': <POINT (30.657 59.973)>,
#  'Градообразующие функции': {'Безопасность': {'Обслуженное население': 0.0},
#                              'Здравоохранение': {'Обслуженное население': 17.0},
#                              'Культура и отдых': {'Обслуженное население': 0.0},
#                              'Образование': {'Обслуженное население': 782.0},
#                              'Социальная помощь': {'Обслуженное население': 0.0},
#                              'Спорт': {'Обслуженное население': 0.0},
#                              'Туризм': {'Обслуженное население': 35.0},
#                              'Услуги': {'Обслуженное население': 307.0}},
#  'Градообслуживающие функции': {'Безопасность': {'Обеспеченность, %': 100.0,
#                                                  'Обслуженное население': 1},
#                                 'Здравоохранение': {'Обеспеченность, %': 100.0,
#                                                     'Обслуженное население': 5},
#                                 'Культура и отдых': {'Обеспеченность, %': 100.0,
#                                                      'Обслуженное население': 20},
#                                 'Образование': {'Обеспеченность, %': 100.0,
#                                                 'Обслуженное население': 20},
#                                 'Социальная помощь': {'Обеспеченность, %': 0.0,
#                                                       'Обслуженное население': 0},
#                                 'Спорт': {'Обеспеченность, %': 100.0,
#                                           'Обслуженное население': 2},
#                                 'Туризм': {'Обеспеченность, %': 94.12,
#                                            'Обслуженное население': 16},
#                                 'Услуги': {'Обеспеченность, %': 69.17,
#                                            'Обслуженное население': 92}},
#  'Лучшая градообразующая функция': 'Образование',
#  'Лучшая градообразующая функция, чел': 782.0,
#  'Лучшая градообслуживающая функция': 'Образование',
#  'Лучшая градообслуживающая функция, %': 100.0,
#  'Лучшая обеспеченность, %': 100.0,
#  'Название': 'Куйворы',
#  'Население': 713,
#  'Опорный пункт': False,
#  'Потенциальный опорный пункт': True,
#  'Сервисы: градообразующая функция': {'Адвокат': {'Обслуженное население': 0.0},
#                                       'Аквапарк': {'Обслуженное население': 0.0},
#                                       'Аптека': {'Обслуженное население': 17.0},
#                                       'База отдыха': {'Обслуженное население': 0.0},
#                                       'Банкомат': {'Обслуженное население': 0.0},
#                                       'Бар/Паб': {'Обслуженное население': 0.0},
#                                       'Бассейн': {'Обслуженное население': 0.0},
#                                       'Библиотека': {'Обслуженное население': 0.0},
#                                       'Больница': {'Обслуженное население': 0.0},
#                                       'Булочная': {'Обслуженное население': 0.0},
#                                       'Ветеринарная клиника': {'Обслуженное население': 0.0},
#                                       'Высшее учебное заведение': {'Обслуженное население': 0.0},
#                                       'Гостиница': {'Обслуженное население': 0.0},
#                                       'Дворец культуры': {'Обслуженное население': 0.0},
#                                       'Детская больница': {'Обслуженное население': 0.0},
#                                       'Детская поликлиника': {'Обслуженное население': 0.0},
#                                       'Детские дома-интернаты': {'Обслуженное население': 0.0},
#                                       'Детские лагеря': {'Обслуженное население': 0.0},
#                                       'Детский сад': {'Обслуженное население': 594.0},
#                                       'Диспансер': {'Обслуженное население': 0.0},
#                                       'Дом детского творчества': {'Обслуженное население': 0.0},
#                                       'Дом престарелых': {'Обслуженное население': 0.0},
#                                       'Женская консультация': {'Обслуженное население': 0.0},
#                                       'Зоомагазин': {'Обслуженное население': 0.0},
#                                       'Каток': {'Обслуженное население': 0.0},
#                                       'Кафе': {'Обслуженное население': 35.0},
#                                       'Кинотеатр': {'Обслуженное население': 0.0},
#                                       'Ледовая арена': {'Обслуженное население': 0.0},
#                                       'Многофункциональные центры (МФЦ)': {'Обслуженное население': 0.0},
#                                       'Морг': {'Обслуженное население': 0.0},
#                                       'Музей': {'Обслуженное население': 0.0},
#                                       'Нотариальная контора': {'Обслуженное население': 0.0},
#                                       'Общественная баня': {'Обслуженное население': 0.0},
#                                       'Отделение банка': {'Обслуженное население': 0.0},
#                                       'Парикмахер': {'Обслуженное население': 158.0},
#                                       'Парк': {'Обслуженное население': 0.0},
#                                       'Пожарная станция': {'Обслуженное население': 0.0},
#                                       'Поликлиника': {'Обслуженное население': 0.0},
#                                       'Полицейский участок': {'Обслуженное население': 0.0},
#                                       'Почтовое отделение': {'Обслуженное население': 0.0},
#                                       'Пункт выдачи': {'Обслуженное население': 0.0},
#                                       'Реабилитационный центр': {'Обслуженное население': 0.0},
#                                       'Ресторан': {'Обслуженное население': 0.0},
#                                       'Роддом': {'Обслуженное население': 0.0},
#                                       'Салон красоты': {'Обслуженное население': 149.0},
#                                       'Санаторий': {'Обслуженное население': 0.0},
#                                       'Скалодром': {'Обслуженное население': 0.0},
#                                       'Спортивный зал': {'Обслуженное население': 0.0},
#                                       'Среднее специальное учебное заведение': {'Обслуженное население': 0.0},
#                                       'Стадион': {'Обслуженное население': 0.0},
#                                       'Станция скорой медицинской помощи': {'Обслуженное население': 0.0},
#                                       'Столовая': {'Обслуженное население': 0.0},
#                                       'Стоматологическая клиника': {'Обслуженное население': 0.0},
#                                       'Театр': {'Обслуженное население': 0.0},
#                                       'Торговый центр': {'Обслуженное население': 0.0},
#                                       'Травматологические пункты': {'Обслуженное население': 0.0},
#                                       'Фельдшерско-акушерский пункт': {'Обслуженное население': 0.0},
#                                       'Хоспис': {'Обслуженное население': 0.0},
#                                       'Хостел': {'Обслуженное население': 0.0},
#                                       'Центр занятости населения': {'Обслуженное население': 0.0},
#                                       'Школа': {'Обслуженное население': 188.0}},
#  'Сервисы: градообслуживающая функция': {'Адвокат': {'Обеспеченность, %': 0.0,
#                                                      'Обслуженное население': 0},
#                                          'Аквапарк': {'Обеспеченность, %': 0.0,
#                                                       'Обслуженное население': 0},
#                                          'Аптека': {'Обеспеченность, %': 100.0,
#                                                     'Обслуженное население': 2},
#                                          'База отдыха': {'Обеспеченность, %': 100.0,
#                                                          'Обслуженное население': 1},
#                                          'Банкомат': {'Обеспеченность, %': 0.0,
#                                                       'Обслуженное население': 0},
#                                          'Бар/Паб': {'Обеспеченность, %': 100.0,
#                                                      'Обслуженное население': 3},
#                                          'Бассейн': {'Обеспеченность, %': 100.0,
#                                                      'Обслуженное население': 1},
#                                          'Библиотека': {'Обеспеченность, %': 0.0,
#                                                         'Обслуженное население': 0},
#                                          'Больница': {'Обеспеченность, %': 100.0,
#                                                       'Обслуженное население': 1},
#                                          'Булочная': {'Обеспеченность, %': 100.0,
#                                                       'Обслуженное население': 1},
#                                          'Ветеринарная клиника': {'Обеспеченность, %': 0.0,
#                                                                   'Обслуженное население': 0},
#                                          'Высшее учебное заведение': {'Обеспеченность, %': 100.0,
#                                                                       'Обслуженное население': 2},
#                                          'Гостиница': {'Обеспеченность, %': 100.0,
#                                                        'Обслуженное население': 1},
#                                          'Дворец культуры': {'Обеспеченность, %': 0.0,
#                                                              'Обслуженное население': 0},
#                                          'Детская больница': {'Обеспеченность, %': 0.0,
#                                                               'Обслуженное население': 0},
#                                          'Детская поликлиника': {'Обеспеченность, %': 0.0,
#                                                                  'Обслуженное население': 0},
#                                          'Детские дома-интернаты': {'Обеспеченность, %': 0.0,
#                                                                     'Обслуженное население': 0},
#                                          'Детские лагеря': {'Обеспеченность, %': 0.0,
#                                                             'Обслуженное население': 0},
#                                          'Детский сад': {'Обеспеченность, %': 100.0,
#                                                          'Обслуженное население': 6},
#                                          'Диспансер': {'Обеспеченность, %': 0.0,
#                                                        'Обслуженное население': 0},
#                                          'Дом детского творчества': {'Обеспеченность, %': 0.0,
#                                                                      'Обслуженное население': 0},
#                                          'Дом престарелых': {'Обеспеченность, %': 0.0,
#                                                              'Обслуженное население': 0},
#                                          'Женская консультация': {'Обеспеченность, %': 0.0,
#                                                                   'Обслуженное население': 0},
#                                          'Зоомагазин': {'Обеспеченность, %': 0.0,
#                                                         'Обслуженное население': 0},
#                                          'Каток': {'Обеспеченность, %': 0.0,
#                                                    'Обслуженное население': 0},
#                                          'Кафе': {'Обеспеченность, %': 100.0,
#                                                   'Обслуженное население': 3},
#                                          'Кинотеатр': {'Обеспеченность, %': 100.0,
#                                                        'Обслуженное население': 1},
#                                          'Ледовая арена': {'Обеспеченность, %': 0.0,
#                                                            'Обслуженное население': 0},
#                                          'Многофункциональные центры (МФЦ)': {'Обеспеченность, %': 0.0,
#                                                                               'Обслуженное население': 0},
#                                          'Морг': {'Обеспеченность, %': 0.0,
#                                                   'Обслуженное население': 0},
#                                          'Музей': {'Обеспеченность, %': 100.0,
#                                                    'Обслуженное население': 1},
#                                          'Нотариальная контора': {'Обеспеченность, %': 0.0,
#                                                                   'Обслуженное население': 0},
#                                          'Общественная баня': {'Обеспеченность, %': 0.0,
#                                                                'Обслуженное население': 0},
#                                          'Отделение банка': {'Обеспеченность, %': 100.0,
#                                                              'Обслуженное население': 2},
#                                          'Парикмахер': {'Обеспеченность, %': 100.0,
#                                                         'Обслуженное население': 1},
#                                          'Парк': {'Обеспеченность, %': 100.0,
#                                                   'Обслуженное население': 15},
#                                          'Пожарная станция': {'Обеспеченность, %': 0.0,
#                                                               'Обслуженное население': 0},
#                                          'Поликлиника': {'Обеспеченность, %': 100.0,
#                                                          'Обслуженное население': 2},
#                                          'Полицейский участок': {'Обеспеченность, %': 100.0,
#                                                                  'Обслуженное население': 1},
#                                          'Почтовое отделение': {'Обеспеченность, %': 100.0,
#                                                                 'Обслуженное население': 88},
#                                          'Пункт выдачи': {'Обеспеченность, %': 0.0,
#                                                           'Обслуженное население': 0},
#                                          'Реабилитационный центр': {'Обеспеченность, %': 0.0,
#                                                                     'Обслуженное население': 0},
#                                          'Ресторан': {'Обеспеченность, %': 100.0,
#                                                       'Обслуженное население': 7},
#                                          'Роддом': {'Обеспеченность, %': 0.0,
#                                                     'Обслуженное население': 0},
#                                          'Салон красоты': {'Обеспеченность, %': 100.0,
#                                                            'Обслуженное население': 1},
#                                          'Санаторий': {'Обеспеченность, %': 0.0,
#                                                        'Обслуженное население': 0},
#                                          'Скалодром': {'Обеспеченность, %': 0.0,
#                                                        'Обслуженное население': 0},
#                                          'Спортивный зал': {'Обеспеченность, %': 0.0,
#                                                             'Обслуженное население': 0},
#                                          'Среднее специальное учебное заведение': {'Обеспеченность, %': 0.0,
#                                                                                    'Обслуженное население': 0},
#                                          'Стадион': {'Обеспеченность, %': 100.0,
#                                                      'Обслуженное население': 1},
#                                          'Станция скорой медицинской помощи': {'Обеспеченность, %': 0.0,
#                                                                                'Обслуженное население': 0},
#                                          'Столовая': {'Обеспеченность, %': 0.0,
#                                                       'Обслуженное население': 0},
#                                          'Стоматологическая клиника': {'Обеспеченность, %': 0.0,
#                                                                        'Обслуженное население': 0},
#                                          'Театр': {'Обеспеченность, %': 100.0,
#                                                    'Обслуженное население': 1},
#                                          'Торговый центр': {'Обеспеченность, %': 100.0,
#                                                             'Обслуженное население': 1},
#                                          'Травматологические пункты': {'Обеспеченность, %': 0.0,
#                                                                        'Обслуженное население': 0},
#                                          'Фельдшерско-акушерский пункт': {'Обеспеченность, %': 0.0,
#                                                                           'Обслуженное население': 0},
#                                          'Хоспис': {'Обеспеченность, %': 0.0,
#                                                     'Обслуженное население': 0},
#                                          'Хостел': {'Обеспеченность, %': 0.0,
#                                                     'Обслуженное население': 0},
#                                          'Центр занятости населения': {'Обеспеченность, %': 0.0,
#                                                                        'Обслуженное население': 0},
#                                          'Школа': {'Обеспеченность, %': 100.0,
#                                                    'Обслуженное население': 12}}}

# %%
gdf = model.get_profilies()
gdf[gdf['Потенциальный опорный пункт'] == True]
# Out:
#       city_id        Название  Население  Опорный пункт  \
# 208       208  Большой Остров        116          False
# 236       236  Сельхозтехника        116          False
# 243       243      Головачово         59          False
# 246       246         Заборье         61          False
# 263       263          Ольеши         58          False
# ...       ...             ...        ...            ...
# 3113     3113      Староселье         94          False
# 3118     3118        Ям-Ижора       6778          False
# 3119     3119      Войскорово       6776          False
# 3121     3121        Тельмана       6663          False
# 3122     3122   Трубников Бор        104          False
#
#       Потенциальный опорный пункт Лучшая градообразующая функция  \
# 208                          True                         Туризм
# 236                          True                         Услуги
# 243                          True                Здравоохранение
# 246                          True                         Услуги
# 263                          True                         Услуги
# ...                           ...                            ...
# 3113                         True                         Туризм
# 3118                         True                    Образование
# 3119                         True                    Образование
# 3121                         True                         Услуги
# 3122                         True               Культура и отдых
#
#       Лучшая градообразующая функция, чел                   geometry
# 208                                  96.0    POINT (33.786 59.47518)
# 236                                1791.0   POINT (33.8095 59.48441)
# 243                                 109.0  POINT (35.43393 59.51748)
# 246                                1519.0  POINT (35.24354 59.52142)
# 263                                1918.0    POINT (35.4089 59.6967)
# ...                                   ...                        ...
# 3113                                496.0  POINT (31.17724 59.61569)
# 3118                                162.0  POINT (30.57305 59.70478)
# 3119                                171.0  POINT (30.56024 59.69105)
# 3121                               7910.0  POINT (30.61175 59.72616)
# 3122                                592.0  POINT (31.39674 59.26628)
#
# [510 rows x 8 columns]

# %%
mf = model.ml_features.copy()
X = model._build_city_feature_matrix()

# Пороговая логика
idx_thr = np.quantile(mf["index"], 0.75)
anom_thr = np.quantile(mf["anomaly_score"].dropna(), 0.95) if "anomaly_score" in mf else np.inf

labels = []
for cid, row in mf.iterrows():
    idx_h = row["index"] >= idx_thr
    anom_h = ("anomaly_score" in row) and (row.get("anomaly_score", np.nan) >= anom_thr)
    if idx_h and not anom_h:
        lab = "high_index_low_anomaly"
    elif idx_h and anom_h:
        lab = "high_index_high_anomaly"
    elif (not idx_h) and anom_h:
        lab = "low_index_high_anomaly"
    else:
        lab = "low_index_low_anomaly"
    labels.append((cid, lab))

groups = pd.DataFrame(labels, columns=["city_id","quadrant"]).set_index("city_id")

# Диагностика отличий: средние по сервисам для каждой группы
def summarize_group(name):
    members = groups.index[groups["quadrant"] == name]
    if len(members) == 0:
        return None, None
    Xg = X.loc[members]
    mean_diff = (Xg.mean() - X.mean()).sort_values(ascending=False)
    top_up = mean_diff.head(5)
    top_down = mean_diff.tail(5)
    return top_up, top_down

for q in ["high_index_low_anomaly","high_index_high_anomaly","low_index_high_anomaly","low_index_low_anomaly"]:
    up, down = summarize_group(q)
    print(f"\n=== {q} ===")
    if up is None:
        print("Нет городов в группе")
        continue
    print("Топ + отличий (среднее - общее среднее):")
    display(up)
    print("Топ - отличий:")
    display(down)
# Out:
# === high_index_low_anomaly ===
# Топ + отличий (среднее - общее среднее):
# Кафе__provision_pct              58.961768
# Аптека__provision_pct            56.663005
# Парикмахер__provision_pct        52.962510
# Ресторан__provision_pct          51.006249
# Торговый центр__provision_pct    48.965953
# dtype: float64
# Топ - отличий:
# Высшее учебное заведение__external_pct   -40.992340
# Парикмахер__external_pct                 -46.480080
# Торговый центр__external_pct             -48.863599
# Аптека__external_pct                     -54.377096
# Кафе__external_pct                       -55.072310
# dtype: float64
# === high_index_high_anomaly ===
# Топ + отличий (среднее - общее среднее):
# Булочная__provision_pct         70.647681
# Аптека__provision_pct           63.933768
# Кафе__provision_pct             63.921354
# Парикмахер__provision_pct       62.030719
# Салон красоты__provision_pct    57.089275
# dtype: float64
# Топ - отличий:
# Полицейский участок__external_pct   -45.051803
# Булочная__external_pct              -52.496880
# Парикмахер__external_pct            -55.548289
# Кафе__external_pct                  -60.031896
# Аптека__external_pct                -61.647859
# dtype: float64
# === low_index_high_anomaly ===
# Топ + отличий (среднее - общее среднее):
# Кафе__provision_pct            37.450766
# Салон красоты__external_pct    32.416268
# Хостел__provision_pct          30.882872
# Аптека__provision_pct          29.905473
# Адвокат__external_pct          28.925853
# dtype: float64
# Топ - отличий:
# База отдыха__external_pct                 -16.636595
# Театр__external_pct                       -18.191435
# Центр занятости населения__external_pct   -27.440444
# Аптека__external_pct                      -27.619564
# Кафе__external_pct                        -33.561308
# dtype: float64
# === low_index_low_anomaly ===
# Топ + отличий (среднее - общее среднее):
# Кафе__external_pct                        20.278254
# Аптека__external_pct                      19.934063
# Парикмахер__external_pct                  16.435864
# Торговый центр__external_pct              15.729286
# Высшее учебное заведение__external_pct    13.228233
# dtype: float64
# Топ - отличий:
# Торговый центр__provision_pct   -15.767909
# Ресторан__provision_pct         -17.166656
# Парикмахер__provision_pct       -18.882006
# Аптека__provision_pct           -20.796650
# Кафе__provision_pct             -21.745939
# dtype: float64

# %%
# OUTPUT_JSON.parent.mkdir(parents=True, exist_ok=True)
# model.save_city_json(OUTPUT_JSON, by="id")
# print(f"Результат сохранён в {OUTPUT_JSON}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for group, data in model.ml_features.groupby('cluster'):
    plt.hist(
        data['anomaly_score'],
        bins=30,
        alpha=0.5,
        label=f'Cluster {group}',
    )

plt.xlabel('Anomaly Score')
plt.ylabel('Count')
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 6))
for group, data in model.ml_features.groupby('cluster'):
    plt.hist(
        data['index'],
        bins=30,
        alpha=0.5,
        label=f'Cluster {group}',
    )

plt.xlabel('index')
plt.ylabel('Count')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
for group, data in model.ml_features.groupby('cluster'):
    plt.scatter(
        data['index'],
        data['anomaly_score'],
        alpha=0.6,
        label=f'Cluster {group}',
        s=20
    )

plt.axhline(0, color='black', linewidth=1)
plt.xlabel('Index')
plt.ylabel('Anomaly Score')
plt.legend()
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 6))
plt.scatter(
        model.ml_features['pca1'],
        model.ml_features['pca2'],
        alpha=0.6,
        label=f'Cluster {group}',
        s=20
    )
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.tight_layout()
plt.show()

# %%
# Анализ: приоритетное развитие и потенциально опорные пункты (ПОП)
from IPython.display import display

ml = model.ml_features.copy()
if 'anomaly_score' not in ml.columns:
    ml['anomaly_score'] = np.nan

idx_hi = ml['index'].quantile(0.75)
idx_lo = ml['index'].quantile(0.25)
anom_hi = ml['anomaly_score'].quantile(0.90) if ml['anomaly_score'].notna().any() else np.inf
anom_lo = ml['anomaly_score'].quantile(0.30) if ml['anomaly_score'].notna().any() else -np.inf

ml['quadrant'] = (
    np.where(ml['index'] >= idx_hi, 'high', 'low') + '_index_' +
    np.where(ml['anomaly_score'] >= anom_hi, 'high', 'low') + '_anomaly'
)

print(f"anomaly high: {anom_hi:.2f}, low: {anom_lo:2f}")
# Out:
# anomaly high: 0.07, low: -0.019206

# %%
# Агрегированные показатели по всем сервисным группам
totals = []
for df_group in model.group_aggregates.values():
    totals.append(df_group[['demand','served','external_demand']])
totals = pd.concat(totals).groupby(level=0).sum()
totals['overall_provision_pct'] = (totals['served'] / totals['demand']).replace([np.inf,-np.inf], np.nan).clip(0, 1) * 100
totals['external_share_pct'] = (totals['external_demand'] / totals['demand']).replace([np.inf,-np.inf], np.nan).clip(lower=0) * 100

# %%
base = pd.concat([
    ml[['index','anomaly_score','quadrant']],
    totals[['overall_provision_pct','external_share_pct']],
    model.city_info[['city_name','population','is_anchor', 'geometry']],
], axis=1)
base['external_supply'] = model._external_supply_total.reindex(base.index).fillna(0.0)
base['external_supply_per_1k'] = base['external_supply'] / (base['population'].replace(0, np.nan) / 1000)
base['external_supply_per_1k'] = base['external_supply_per_1k'].replace([np.inf,-np.inf], np.nan)

# %%
# Города, требующие первостепенного развития
ext_thr = base['external_share_pct'].quantile(0.75)
prov_thr = base['overall_provision_pct'].quantile(0.25)
need_mask = (
    (base['index'] <= idx_lo) |
    (base['overall_provision_pct'] <= prov_thr) |
    (base['external_share_pct'] >= ext_thr)
)
if ml['anomaly_score'].notna().any():
    need_mask |= base['anomaly_score'] >= anom_hi
base['priority_score'] = (
    (100 - base['index']).clip(lower=0) * 0.4 +
    base['external_share_pct'].fillna(0) * 0.3 +
    (100 - base['overall_provision_pct']).clip(lower=0) * 0.3
)
priority_cities = base[need_mask].sort_values('priority_score', ascending=False)
print('Города, требующие первостепенного развития:')
display(priority_cities[['city_name','index','overall_provision_pct','external_share_pct','anomaly_score','priority_score','quadrant']])
# Out:
# Города, требующие первостепенного развития:
#          city_name       index  overall_provision_pct  external_share_pct  \
# 1911   Бородинское    8.426081               0.547046           93.435449
# 1916     Свободное    8.426081               0.617284           92.592593
# 2952      Пашозеро    4.195381               0.000000           85.682819
# 272         Утишье    0.876485               0.583090           81.049563
# 396       Сидорово    3.730890               0.000000           82.795699
# ...            ...         ...                    ...                 ...
# 963      Новоселье   87.838153              96.179982            2.920110
# 951      Харевщина   88.543083              95.238095            1.785714
# 953          Янега   88.543083              96.860525            1.183736
# 1760       Заневка   88.268301              97.052402            0.982533
# 1267  Сосновый бор  100.000000             100.000000            0.000000
#
#       anomaly_score  priority_score                 quadrant
# 1911       0.050453       94.496088    low_index_low_anomaly
# 1916       0.050453       94.222160    low_index_low_anomaly
# 2952       0.006716       94.026693    low_index_low_anomaly
# 272       -0.005773       93.789348    low_index_low_anomaly
# 396        0.036476       93.346354    low_index_low_anomaly
# ...             ...             ...                      ...
# 963        0.078681        6.886777  high_index_high_anomaly
# 951        0.078163        6.547052  high_index_high_anomaly
# 953        0.078163        5.879730  high_index_high_anomaly
# 1760       0.078067        5.871719  high_index_high_anomaly
# 1267       0.082440        0.000000  high_index_high_anomaly
#
# [1458 rows x 7 columns]

# %%
# Потенциально опорные пункты
supply_thr = base['external_supply_per_1k'].quantile(0.75)
pop_mask = (
    (base['external_supply_per_1k'] >= supply_thr) &
    (base['index'] >= idx_hi) &
    (~base['is_anchor'])
)
if ml['anomaly_score'].notna().any():
    pop_mask &= base['anomaly_score'] <= anom_lo
pop_candidates = base[pop_mask].sort_values(['external_supply_per_1k','index'], ascending=[False, False])
pop_candidates = gpd.GeoDataFrame(pop_candidates, geometry='geometry', crs=model.city_info.crs)
print('Потенциально опорные пункты :')
display(pop_candidates[['city_name','index','external_supply','external_supply_per_1k','anomaly_score','quadrant']])
# Out:
# Потенциально опорные пункты :
#             city_name      index  external_supply  external_supply_per_1k  \
# 2155        Руссолово  84.439371              0.0                     0.0
# 2218  Большие Борницы  69.231082              0.0                     0.0
#
#       anomaly_score                quadrant
# 2155      -0.019206  high_index_low_anomaly
# 2218      -0.024284  high_index_low_anomaly

# %%
pop_candidates.explore(tiles='CartoDB Positron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23f44e9ca0d39be86e740f681e1936ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23f44e9ca0d39be86e740f681e1936ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23f44e9ca0d39be86e740f681e1936ad = L.map(
#                 &quot;map_23f44e9ca0d39be86e740f681e1936ad&quot;,
#                 {
#                     center: [59.55918600417855, 30.057712544823914],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_23f44e9ca0d39be86e740f681e1936ad);
#
#
#
#
#
#             var tile_layer_91523aa0f591cb84e6e26725691ecdcb = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91523aa0f591cb84e6e26725691ecdcb.addTo(map_23f44e9ca0d39be86e740f681e1936ad);
#
#
#             map_23f44e9ca0d39be86e740f681e1936ad.fitBounds(
#                 [[59.510190313059304, 29.891380365327844], [59.608181695297795, 30.224044724319988]],
#                 {}
#             );
#
#
#         function geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3666c4dc5c14a60fc41f6c4e26ed087f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3666c4dc5c14a60fc41f6c4e26ed087f = L.geoJson(null, {
#                 onEachFeature: geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_onEachFeature,
#
#                 style: geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_styler,
#                 pointToLayer: geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_add (data) {
#             geo_json_3666c4dc5c14a60fc41f6c4e26ed087f
#                 .addData(data);
#         }
#             geo_json_3666c4dc5c14a60fc41f6c4e26ed087f_add({&quot;bbox&quot;: [29.891380365327844, 59.510190313059304, 30.224044724319988, 59.608181695297795], &quot;features&quot;: [{&quot;bbox&quot;: [30.224044724319988, 59.608181695297795, 30.224044724319988, 59.608181695297795], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.224044724319988, 59.608181695297795], &quot;type&qu
